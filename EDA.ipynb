# %%
from data_utils import *

# %%
train_data = makeTrainingData(
    train_csv='train.csv',
    decription_csv='product_descriptions.csv',
    attrib_csv='attributes.csv',
    merge_col='product_uid'
)

# %%
train_data
# Out:
#            id  product_uid                                      product_title  \
# 0           2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1           3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2           9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3          16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4          17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# ...       ...          ...                                                ...
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
# ...

# %%
print('Distinct Search Terms =',train_data['search_term'].nunique())
print('Distinct Products =',train_data['product_uid'].nunique())
print('Distinct Brands =',train_data['brand'].nunique())
# Out:
# Distinct Search Terms = 11795
# Distinct Products = 54667
# Distinct Brands = 3142

# %%
test_data = pd.read_csv(os.path.join('data','test_new.csv'))

# %%
test_data
# Out:
#        Unnamed: 0   _unit_id  relevance  relevance:variance  \
# 0               0  711158459       3.67               0.471
# 1               1  711158460       4.00               0.000
# 2               2  711158461       4.00               0.000
# 3               3  711158462       3.67               0.471
# 4               4  711158463       3.33               0.471
# ...           ...        ...        ...                 ...
# 19573       25545  713189511        NaN                 NaN
# 19574       25546  713189512        NaN                 NaN
# 19575       25547  713189513        NaN                 NaN
# 19576       25548  713189514        NaN                 NaN
# 19577       25549  713189515        NaN                 NaN
#
#                                            product_image  \
# 0      http://thumbs2.ebaystatic.com/d/l225/m/mzvzEUI...
# 1      http://thumbs3.ebaystatic.com/d/l225/m/mJNDmSy...
# 2      http://thumbs4.ebaystatic.com/d/l225/m/m10NZXA...
# ...

# %%
print('Distinct Search Terms =',test_data['query'].nunique())
print('Distinct Products =',test_data['_unit_id'].nunique())
print('Distinct Brands =',test_data['brand'].nunique())
# Out:
# Distinct Search Terms = 261
# Distinct Products = 19578
# Distinct Brands = 1487
